# %% [markdown]
# Loading Data

# %%
import pandas as pd
raw_data = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")


raw_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# Information Regarding Data

# %%
raw_data.shape
# Out:
# (7043, 21)

# %%
raw_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# Null values

# %%
raw_data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Churn Value Count

# %%
raw_data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
raw_data['Churn'].value_counts(normalize=True).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# Monthly Charges and Churn relation

# %%
import seaborn as sns
sns.boxplot(x='Churn', y='MonthlyCharges', data=raw_data)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# Contract and Churn

# %%
sns.countplot(x='Contract', hue='Churn', data=raw_data)
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# Contract and Churn

# %%
pd.crosstab(raw_data['Contract'], raw_data['Churn'], normalize='index') * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %% [markdown]
# Tenure and Churn

# %%
sns.histplot(x='tenure', hue='Churn', data=raw_data, bins=30)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# Categorical features overview

# %%
import matplotlib.pyplot as plt
cat_cols = ['InternetService', 'PaymentMethod', 'gender', 'SeniorCitizen', 'Partner', 'Dependents']
for col in cat_cols:
    raw_data.groupby([col, 'Churn']).size().unstack().plot(kind='bar')
    plt.show()
